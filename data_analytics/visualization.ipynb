# %% [markdown]
# VISUALIZATION
# - figure
# - axes
# - plot
# - pie

# %%
import matplotlib.pyplot as plt
import numpy as numpy

# %%
y = [21,3,4,5,6,12,45,23]
plt.plot(y)

# %%
plt.figure(figsize=(15,4))
plt.pie(y)
plt.show()
